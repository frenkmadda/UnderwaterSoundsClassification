# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_metrics(file_path):
    # Carica il file CSV
    df = pd.read_csv(file_path)

    # Numero di metriche da plottare (escludendo 'epoch')
    num_metrics = len([col for col in df.columns[1:] if 'train' in col])

    # Numero di righe e colonne per la griglia di subplot
    num_rows = int(np.ceil(num_metrics / 2))
    num_cols = 2

    # Crea una figura
    plt.figure(figsize=(10, 6 * num_rows))

    # Per ogni metrica nel DataFrame (esclusa la colonna 'epoch')
    for i, metric in enumerate(df.columns[1:], start=1):
        if 'train' in metric:
            # Crea un subplot nella griglia
            plt.subplot(num_rows, num_cols, i)

            # Plot della metrica di training
            plt.plot(df['epoch'], df[metric], label=metric, color='blue')

            # Plot della corrispondente metrica di validation
            val_metric = metric.replace('train', 'val')
            if val_metric in df.columns:
                plt.plot(df['epoch'], df[val_metric], label=val_metric, color='red')

            # Imposta le etichette degli assi e il titolo
            plt.xlabel('Epoch')
            plt.ylabel(metric.split('_')[1])
            plt.title(f'Train vs Validation {metric.split("_")[1]}')

            # Mostra la legenda
            plt.legend()

    # Mostra la griglia di grafici
    plt.tight_layout()
    plt.show()

# %%
def plot_precision_recall(file_path):
    # Carica il file CSV
    df = pd.read_csv(file_path)

    # Plot Precision vs Recall per il training
    plt.figure(figsize=(6, 6))
    plt.plot(df['train_recall'], df['train_precision'], marker='o', color='blue', label='Train')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Training Precision vs Recall')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Precision vs Recall per la validation
    plt.figure(figsize=(6, 6))
    plt.plot(df['val_recall'], df['val_precision'], marker='x', color='red', label='Validation')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Validation Precision vs Recall')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Plot delle metriche di training sul classificatore binario con average=binary effettuato con GoogleNet

# %%
plot_metrics('results/training_metrics.csv')

# %%
#plot_precision_recall('results/training_metrics.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore binario con average=weighted effettuato con GoogleNet

# %%
plot_metrics('results/test2_google_net.csv')

# %%
#plot_precision_recall('results/test2_google_net.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore binario con average=macro effettuato con GoogleNet

# %%
plot_metrics('results/test3_google_net.csv')

# %%
#plot_precision_recall('results/test3_google_net.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore binario con average=micro effettuato con GoogleNet

# %%
plot_metrics('results/test4_google_net.csv')

# %%
#plot_precision_recall('results/test4_google_net.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore binario con average=weighted effettuato con AlexNet

# %%
plot_metrics('results/test5_alex_net.csv')

# %%
#plot_precision_recall('results/test5_alex_net.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con average=weighted effettuato con googleNet

# %%
plot_metrics('results/test8_google_net.csv')

# %%
#plot_precision_recall('results/test8_google_net.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con average=weighted effettuato con googleNet con One Hot encoding

# %%
plot_metrics('results/test8_google_net_one_hot.csv')

# %%
#plot_precision_recall('results/test8_google_net_one_hot.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con average=macro effettuato con googleNet

# %%
plot_metrics('results/test9_google_net.csv')

# %%
#plot_precision_recall('results/test9_google_net.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con average=macro effettuato con googleNet con One Hot encoding

# %%
plot_metrics('results/test9_google_net_one_hot.csv')

# %%
plot_precision_recall('results/test9_google_net_one_hot.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con average=micro effettuato con googleNet

# %%
plot_metrics('results/test10_google_net.csv')

# %%
#plot_precision_recall('results/test10_google_net.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con average=micro effettuato con googleNet con One Hot encoding

# %%
plot_metrics('results/test10_google_net_one_hot.csv')

# %%
#plot_precision_recall('results/test10_google_net_one_hot.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con tecnica di One Hot Encoding effettuato con AlexNet

# %%
plot_metrics('results/test11_alex_net_one_hot.csv')

# %%
#plot_precision_recall('results/test11_alex_net_one_hot.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con tecnica di One Hot Encoding effettuato con ResNet50 con average=weighted e dataset sbilanciato

# %%
plot_metrics('results/test13_res_net_one_hot_unbalanced.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con tecnica di One Hot Encoding effettuato con AlexNet con average=weighted e dataset sbilanciato

# %%
plot_metrics('results/test15_alex_net_one_hot_unbalanced.csv')

# %% [markdown]
# # Plot delle metriche di training sul classificatore multiclasse con tecnica di One Hot Encoding effettuato con GoogleNet con average=weighted e dataset sbilanciato

# %%
plot_metrics('results/test18_google_net_one_hot_unbalanced.csv')
